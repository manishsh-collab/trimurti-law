# %% [markdown]
# # 🏛️ Trimurti LAW - Cloud Training
# **Run your legal AI training on Google's free GPU**
#
# ---
# ### Instructions:
# 1. Click `Runtime` → `Change runtime type` → Select **T4 GPU**
# 2. Run each cell in order (Shift+Enter)
# 3. Training runs in the cloud - your local machine stays free!

# %%
# Step 1: Mount Google Drive (for saving models)
from google.colab import drive
drive.mount('/content/drive')
print('✅ Google Drive mounted!')

# %%
# Step 2: Clone your project from GitHub (or upload files)
# Option A: Clone from GitHub
# !git clone https://github.com/YOUR_USERNAME/trimurti-law.git

# Option B: Upload files manually
from google.colab import files
print('📁 Upload your project files or clone from GitHub')

# %%
# Step 3: Install dependencies
# !pip install streamlit pandas numpy altair plotly pypdf google-generativeai sentence-transformers
print('✅ Dependencies installed!')

# %%
# Step 4: Check GPU availability
import torch
print(f'🖥️ GPU Available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'🔥 GPU: {torch.cuda.get_device_name(0)}')
    print(f'💾 GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB')

# %%
# Step 5: Run Training (example)
# Replace with your actual training code

# Example: Train on legal documents
TRAINING_URL = "https://www.law.cornell.edu"  # Change this

print(f'🚀 Starting cloud training on: {TRAINING_URL}')
print('💡 Your local machine is free while training runs here!')

# %%
# Step 6: Save trained model to Google Drive
import shutil

# Copy training results to Drive
# shutil.copy('training_history.json', '/content/drive/MyDrive/Trimurti_LAW/')
print('💾 Save your models to /content/drive/MyDrive/Trimurti_LAW/')
